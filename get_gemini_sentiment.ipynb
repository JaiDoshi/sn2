# %%
import os
# os.chdir('./sn2')
import re
import pandas as pd
import json
import numpy as np
import time

# %%
import google.generativeai as genai
from dotenv import load_dotenv
load_dotenv()
#fine tuned model saved with gemini_token3
gemini_api_key = os.getenv("GEMINI_TOKEN")
genai.configure(api_key=gemini_api_key)

# %%
gemini_api_key
# Out:
# 'AIzaSyDRQsc6gkGXsWP-VnXZFBiw1lrcp2nEPU0'

# %%
selected_companies = ["AAPL", "KO", "V", "XOM", "TSLA"]
tweet_dir = "./tweet/raw/"


def get_tweets(ticker, date_str):
        print(f"Getting tweets for {ticker} on {date_str}")
        tweets = []
        tweet_path = os.path.join(tweet_dir, ticker, date_str)

        if os.path.exists(tweet_path):
            with open(tweet_path) as f:
                lines = f.readlines()
                for line in lines:
                    tweet_obj = json.loads(line)
                    tweets.append(tweet_obj['text'])
        return tweets

apple_daily_tweets = {}
for date_str in sorted(os.listdir(f"{tweet_dir}{selected_companies[0]}")):
    apple_daily_tweets[date_str] = get_tweets(selected_companies[0], date_str)
print(len(apple_daily_tweets))
# Out:
# Getting tweets for AAPL on 2020-01-01
# Getting tweets for AAPL on 2020-01-02
# Getting tweets for AAPL on 2020-01-03
# Getting tweets for AAPL on 2020-01-04
# Getting tweets for AAPL on 2020-01-05
# Getting tweets for AAPL on 2020-01-06
# Getting tweets for AAPL on 2020-01-07
# Getting tweets for AAPL on 2020-01-08
# Getting tweets for AAPL on 2020-01-09
# Getting tweets for AAPL on 2020-01-10
# Getting tweets for AAPL on 2020-01-11
# Getting tweets for AAPL on 2020-01-12
# Getting tweets for AAPL on 2020-01-13
# Getting tweets for AAPL on 2020-01-14
# Getting tweets for AAPL on 2020-01-15
# Getting tweets for AAPL on 2020-01-16
# Getting tweets for AAPL on 2020-01-17
# Getting tweets for AAPL on 2020-01-18
# Getting tweets for AAPL on 2020-01-19
# Getting tweets for AAPL on 2020-01-20
# Getting tweets for AAPL on 2020-01-21
# Getting tweets for AAPL on 2020-01-22
# Getting tweets for AAPL on 2020-01-23
# Getting tweets for AAPL on 2020-01-24
# Getting tweets for AAPL on 2020-01-25
# ...

# %%
coca_daily_tweets = {}
for date_str in sorted(os.listdir(f"{tweet_dir}{selected_companies[1]}")):
    coca_daily_tweets[date_str] = get_tweets(selected_companies[1], date_str)
print(len(coca_daily_tweets))
# Out:
# Getting tweets for KO on 2020-01-07
# Getting tweets for KO on 2020-01-09
# Getting tweets for KO on 2020-01-10
# Getting tweets for KO on 2020-01-11
# Getting tweets for KO on 2020-01-12
# Getting tweets for KO on 2020-01-13
# Getting tweets for KO on 2020-01-14
# Getting tweets for KO on 2020-01-17
# Getting tweets for KO on 2020-01-18
# Getting tweets for KO on 2020-01-20
# Getting tweets for KO on 2020-01-21
# Getting tweets for KO on 2020-01-23
# Getting tweets for KO on 2020-01-24
# Getting tweets for KO on 2020-01-25
# Getting tweets for KO on 2020-01-26
# Getting tweets for KO on 2020-01-27
# Getting tweets for KO on 2020-01-28
# Getting tweets for KO on 2020-01-29
# Getting tweets for KO on 2020-01-30
# Getting tweets for KO on 2020-02-06
# Getting tweets for KO on 2020-02-07
# Getting tweets for KO on 2020-02-08
# Getting tweets for KO on 2020-02-10
# Getting tweets for KO on 2020-02-12
# Getting tweets for KO on 2020-02-19
# Getting tweets for KO on 2020-02-20
# ...

# %%
visa_daily_tweets = {}
for date_str in sorted(os.listdir(f"{tweet_dir}{selected_companies[2]}")):
    visa_daily_tweets[date_str] = get_tweets(selected_companies[2], date_str)
print(len(visa_daily_tweets))
# Out:
# Getting tweets for V on 2020-01-04
# Getting tweets for V on 2020-01-05
# Getting tweets for V on 2020-01-06
# Getting tweets for V on 2020-01-07
# Getting tweets for V on 2020-01-08
# Getting tweets for V on 2020-01-09
# Getting tweets for V on 2020-01-10
# Getting tweets for V on 2020-01-11
# Getting tweets for V on 2020-01-12
# Getting tweets for V on 2020-01-13
# Getting tweets for V on 2020-01-14
# Getting tweets for V on 2020-01-15
# Getting tweets for V on 2020-01-16
# Getting tweets for V on 2020-01-17
# Getting tweets for V on 2020-01-18
# Getting tweets for V on 2020-01-19
# Getting tweets for V on 2020-01-20
# Getting tweets for V on 2020-01-21
# Getting tweets for V on 2020-01-22
# Getting tweets for V on 2020-01-23
# Getting tweets for V on 2020-01-24
# Getting tweets for V on 2020-01-25
# Getting tweets for V on 2020-01-26
# Getting tweets for V on 2020-01-27
# Getting tweets for V on 2020-01-28
# Getting tweets for V on 2020-01-29
# Getting tweets for V on 2020-01-30
# ...

# %%
exxon_daily_tweets = {}
for date_str in sorted(os.listdir(f"{tweet_dir}{selected_companies[3]}")):
    exxon_daily_tweets[date_str] = get_tweets(selected_companies[3], date_str)
print(len(exxon_daily_tweets))
# Out:
# Getting tweets for XOM on 2020-01-05
# Getting tweets for XOM on 2020-01-06
# Getting tweets for XOM on 2020-01-07
# Getting tweets for XOM on 2020-01-08
# Getting tweets for XOM on 2020-01-09
# Getting tweets for XOM on 2020-01-10
# Getting tweets for XOM on 2020-01-11
# Getting tweets for XOM on 2020-01-13
# Getting tweets for XOM on 2020-01-14
# Getting tweets for XOM on 2020-01-15
# Getting tweets for XOM on 2020-01-16
# Getting tweets for XOM on 2020-01-17
# Getting tweets for XOM on 2020-01-19
# Getting tweets for XOM on 2020-01-20
# Getting tweets for XOM on 2020-01-21
# Getting tweets for XOM on 2020-01-22
# Getting tweets for XOM on 2020-01-23
# Getting tweets for XOM on 2020-01-24
# Getting tweets for XOM on 2020-01-25
# Getting tweets for XOM on 2020-01-26
# Getting tweets for XOM on 2020-01-27
# Getting tweets for XOM on 2020-01-28
# Getting tweets for XOM on 2020-01-29
# Getting tweets for XOM on 2020-01-30
# Getting tweets for XOM on 2020-01-31
# ...

# %%
tesla_daily_tweets = {}
for date_str in sorted(os.listdir(f"{tweet_dir}{selected_companies[4]}")):
    tesla_daily_tweets[date_str] = get_tweets(selected_companies[4], date_str)
print(len(tesla_daily_tweets))
# Out:
# Getting tweets for TSLA on 2020-01-04
# Getting tweets for TSLA on 2020-01-05
# Getting tweets for TSLA on 2020-01-06
# Getting tweets for TSLA on 2020-01-07
# Getting tweets for TSLA on 2020-01-08
# Getting tweets for TSLA on 2020-01-09
# Getting tweets for TSLA on 2020-01-10
# Getting tweets for TSLA on 2020-01-11
# Getting tweets for TSLA on 2020-01-12
# Getting tweets for TSLA on 2020-01-13
# Getting tweets for TSLA on 2020-01-14
# Getting tweets for TSLA on 2020-01-15
# Getting tweets for TSLA on 2020-01-16
# Getting tweets for TSLA on 2020-01-17
# Getting tweets for TSLA on 2020-01-18
# Getting tweets for TSLA on 2020-01-19
# Getting tweets for TSLA on 2020-01-20
# Getting tweets for TSLA on 2020-01-21
# Getting tweets for TSLA on 2020-01-22
# Getting tweets for TSLA on 2020-01-23
# Getting tweets for TSLA on 2020-01-24
# Getting tweets for TSLA on 2020-01-25
# Getting tweets for TSLA on 2020-01-26
# Getting tweets for TSLA on 2020-01-27
# Getting tweets for TSLA on 2020-01-28
# ...

# %% [markdown]
# ## Extract labels

# %%
print(selected_companies)
price_path = "./price/raw/"
# AAPL
header = ['date', 'open_price', 'high_price', 'low_price', 'close_price', 'adjusted_close_price', 'volume']
dtypes = {'open_price' : np.float64, 'high_price' : np.float64, 'low_price' : np.float64, 'close_price' : np.float64, 'adjusted_close_price' : np.float64, 'volume' : np.int64}
apple_price = pd.read_csv(price_path + f"{selected_companies[0]}.csv", skiprows = 1, names = header, dtype=dtypes, parse_dates=['date'])
coke_price = pd.read_csv(price_path + f"{selected_companies[1]}.csv",  skiprows = 1, names = header, dtype=dtypes, parse_dates=['date'])
visa_price = pd.read_csv(price_path + f"{selected_companies[2]}.csv", skiprows = 1, names = header, dtype=dtypes, parse_dates=['date'])
exxon_price = pd.read_csv(price_path + f"{selected_companies[3]}.csv", skiprows = 1, names = header, dtype=dtypes, parse_dates=['date'])
tesla_price = pd.read_csv(price_path + f"{selected_companies[4]}.csv", skiprows = 1, names = header, dtype=dtypes, parse_dates=['date'])

# price_path = "./price/preprocessed/"
# header = ['date', 'close price', 'open price', 'high price', 'low price', 'close price change', 'volume']
# apple_price = pd.read_csv(price_path + f"{selected_companies[0]}.txt", sep = '\t', names = header)
# coke_price = pd.read_csv(price_path + f"{selected_companies[1]}.txt", sep = '\t', names = header)
# visa_price = pd.read_csv(price_path + f"{selected_companies[2]}.txt", sep = '\t', names = header)
# exxon_price = pd.read_csv(price_path + f"{selected_companies[3]}.txt", sep = '\t', names = header)
# tesla_price = pd.read_csv(price_path + f"{selected_companies[4]}.txt", sep = '\t', names = header)
tesla_price
# Out:
# ['AAPL', 'KO', 'V', 'XOM', 'TSLA']
#           date  open_price  high_price   low_price  close_price  \
# 0   2019-12-31   81.000000   84.258003   80.416000    83.666000
# 1   2020-01-02   84.900002   86.139999   84.342003    86.052002
# 2   2020-01-03   88.099998   90.800003   87.384003    88.601997
# 3   2020-01-06   88.094002   90.311996   88.000000    90.307999
# 4   2020-01-07   92.279999   94.325996   90.671997    93.811996
# ..         ...         ...         ...         ...          ...
# 752 2022-12-23  126.370003  128.619995  121.019997   123.150002
# 753 2022-12-27  117.500000  119.669998  108.760002   109.099998
# 754 2022-12-28  110.349998  116.269997  108.239998   112.709999
# 755 2022-12-29  120.389999  123.570000  117.500000   121.820000
# 756 2022-12-30  119.949997  124.480003  119.750000   123.180000
#
#      adjusted_close_price     volume
# 0               83.666000   51428500
# 1               86.052002   47660500
# 2               88.601997   88892500
# ...

# %%
# apple_price = pd.concat([apple_price, apple_price[['adjusted_close_price']].shift(1).rename({'adjusted_close_price' : 'shifted_close'}, axis = 1)], axis=1)
# coke_price = pd.concat([coke_price, coke_price[['adjusted_close_price']].shift(1).rename({'adjusted_close_price' : 'shifted_close'}, axis = 1)], axis=1)
# visa_price = pd.concat([visa_price, visa_price[['adjusted_close_price']].shift(1).rename({'adjusted_close_price' : 'shifted_close'}, axis = 1)], axis=1)
# exxon_price = pd.concat([exxon_price, exxon_price[['adjusted_close_price']].shift(1).rename({'adjusted_close_price' : 'shifted_close'}, axis = 1)], axis=1)
# tesla_price = pd.concat([tesla_price, tesla_price[['adjusted_close_price']].shift(1).rename({'adjusted_close_price' : 'shifted_close'}, axis = 1)], axis=1)

apple_price['frac_change'] = apple_price['adjusted_close_price'].pct_change()
coke_price['frac_change'] = coke_price['adjusted_close_price'].pct_change()
visa_price['frac_change'] = visa_price['adjusted_close_price'].pct_change()
exxon_price['frac_change'] = exxon_price['adjusted_close_price'].pct_change()
tesla_price['frac_change'] = tesla_price['adjusted_close_price'].pct_change()

# %%
apple_price
# Out:
#           date  open_price  high_price   low_price  close_price  \
# 0   2019-12-31   72.482498   73.419998   72.379997    73.412498
# 1   2020-01-02   74.059998   75.150002   73.797501    75.087502
# 2   2020-01-03   74.287498   75.144997   74.125000    74.357498
# 3   2020-01-06   73.447502   74.989998   73.187500    74.949997
# 4   2020-01-07   74.959999   75.224998   74.370003    74.597504
# ..         ...         ...         ...         ...          ...
# 752 2022-12-23  130.919998  132.419998  129.639999   131.860001
# 753 2022-12-27  131.380005  131.410004  128.720001   130.029999
# 754 2022-12-28  129.669998  131.029999  125.870003   126.040001
# 755 2022-12-29  127.989998  130.479996  127.730003   129.610001
# 756 2022-12-30  128.410004  129.949997  127.430000   129.929993
#
#      adjusted_close_price     volume  frac_change
# 0               72.552094  100805600          NaN
# 1               74.207466  135480400     0.022816
# ...

# %%
apple_price['label'] = np.where(apple_price['frac_change'] > 0, 1, 0)
coke_price['label'] = np.where(coke_price['frac_change'] > 0, 1, 0)
visa_price['label'] = np.where(visa_price['frac_change'] > 0, 1, 0)
exxon_price['label'] = np.where(exxon_price['frac_change'] > 0, 1, 0)
tesla_price['label'] = np.where(tesla_price['frac_change'] > 0, 1, 0)

tesla_price = tesla_price.drop(0).reset_index(drop=True)
exxon_price = exxon_price.drop(0).reset_index(drop=True)
visa_price = visa_price.drop(0).reset_index(drop=True)
coke_price = coke_price.drop(0).reset_index(drop=True)
apple_price = apple_price.drop(0).reset_index(drop=True)

# %%
apple_label_dict = {}
for d, label in apple_price[['date', 'label']].values:
    apple_label_dict[d.strftime('%Y-%m-%d')] = label

coke_label_dict = {}
for d, label in coke_price[['date', 'label']].values:
    coke_label_dict[d.strftime('%Y-%m-%d')] = label

visa_label_dict = {}
for d, label in visa_price[['date', 'label']].values:
    visa_label_dict[d.strftime('%Y-%m-%d')] = label

exxon_label_dict = {}
for d, label in exxon_price[['date', 'label']].values:
    exxon_label_dict[d.strftime('%Y-%m-%d')] = label

tesla_label_dict = {}
for d, label in tesla_price[['date', 'label']].values:
    tesla_label_dict[d.strftime('%Y-%m-%d')] = label

# %%
path = "./data_split/split_01/"
split1 = pd.read_csv(path + "train.csv", parse_dates=['Date'])

# %%
for date, label in list(apple_label_dict.items()):
    # convert date to datetime
    date = pd.to_datetime(date, format='%Y-%m-%d')
    # only keep keys in apple_label_dict which are before the first split
    if not date < split1['Date'].min():
        apple_label_dict.pop(date.strftime('%Y-%m-%d'))

for date, label in list(coke_label_dict.items()):
    # convert date to datetime
    date = pd.to_datetime(date, format='%Y-%m-%d')
    # only keep keys in apple_label_dict which are before the first split
    if not date < split1['Date'].min():
        coke_label_dict.pop(date.strftime('%Y-%m-%d'))

for date, label in list(visa_label_dict.items()):
    # convert date to datetime
    date = pd.to_datetime(date, format='%Y-%m-%d')
    # only keep keys in apple_label_dict which are before the first split
    if not date < split1['Date'].min():
        visa_label_dict.pop(date.strftime('%Y-%m-%d'))

for date, label in list(exxon_label_dict.items()):
    # convert date to datetime
    date = pd.to_datetime(date, format='%Y-%m-%d')
    # only keep keys in apple_label_dict which are before the first split
    if not date < split1['Date'].min():
        exxon_label_dict.pop(date.strftime('%Y-%m-%d'))

for date, label in list(tesla_label_dict.items()):
    # convert date to datetime
    date = pd.to_datetime(date, format='%Y-%m-%d')
    # only keep keys in apple_label_dict which are before the first split
    if not date < split1['Date'].min():
        tesla_label_dict.pop(date.strftime('%Y-%m-%d'))

# %% [markdown]
# ## Prep training data for gemini

# %%
from datetime import datetime, timedelta

def get_next_date(date_str):
    """
    Get the next day's date as a string.

    :param date_str: Date string in 'YYYY-MM-DD' format.
    :return: Next day's date as a string in 'YYYY-MM-DD' format.
    """
    date = datetime.strptime(date_str, '%Y-%m-%d')
    next_day = date + timedelta(days=1)
    return next_day.strftime('%Y-%m-%d')

def prepare_training_data(tweet_data, price_changes, system_instruction, training_data = []):
    """
    Prepare training data for fine-tuning.

    :param tweet_data: Dictionary with date as key and list of tweets as value.
    :param price_changes: Dictionary with date as key and price change (+1, -1) as value.
    :param system_instruction: System instruction string.
    :return: List of dictionaries formatted for fine-tuning.
    """

    for date, tweets in tweet_data.items():
        # Combine all tweets for the date into a single text block
        tweets_text = " ".join(tweets)
        
        # Ensure the next day's price change exists
        next_day = get_next_date(date)  # Implement get_next_date to fetch the next day
        if next_day in price_changes:
            label = price_changes[next_day]

            # Construct text_input with the system instruction and tweets
            text_input = f"{system_instruction} {tweets_text}"
            
            # Add the formatted example to the training data
            training_data.append({
                'text_input': text_input,
                'output': str(label)  # Convert label to string as expected in fine-tuning
            })
        else:
            continue
    return training_data

# %%
apple_prompt = "Forget all your previous instructions. Pretend you are a financial expert. You are a financial expert with stock recommendation experience adept at analysing the effect of tweets on stock price. Predict the next-day price movement of the stock for Apple Inc. (AAPL) based on the following tweets. Your prediction should be binary,\
 1 for positive price movement and 0 for negative price movement. Only give the prediction as your response, nothing else. Here are the tweets from today: "

coke_prompt = "Forget all your previous instructions. Pretend you are a financial expert. You are a financial expert with stock recommendation experience adept at analysing the effect of tweets on stock price. Predict the next-day price movement of the stock for The Coca-Cola Company (KO) based on the following tweets. Your prediction should be binary,\
 1 for positive price movement and 0 for negative price movement. Only give the prediction as your response, nothing else. Here are the tweets from today: "

visa_prompt = "Forget all your previous instructions. Pretend you are a financial expert. You are a financial expert with stock recommendation experience adept at analysing the effect of tweets on stock price. Predict the next-day price movement of the stock for Visa Inc. (V) based on the following tweets. Your prediction should be binary,\
 1 for positive price movement and 0 for negative price movement. Only give the prediction as your response, nothing else. Here are the tweets from today: "

exxon_prompt = "Forget all your previous instructions. Pretend you are a financial expert. You are a financial expert with stock recommendation experience adept at analysing the effect of tweets on stock price. Predict the next-day price movement of the stock for Exxon Mobil Corporation (XOM) based on the following tweets. Your prediction should be binary,\
 1 for positive price movement and 0 for negative price movement. Only give the prediction as your response, nothing else. Here are the tweets from today: "

tesla_prompt = "Forget all your previous instructions. Pretend you are a financial expert. You are a financial expert with stock recommendation experience adept at analysing the effect of tweets on stock price. Predict the next-day price movement of the stock for Tesla, Inc. (TSLA) based on the following tweets. Your prediction should be binary,\
 1 for positive price movement and 0 for negative price movement. Only give the prediction as your response, nothing else. Here are the tweets from today: "
 
training_data = prepare_training_data(apple_daily_tweets, apple_label_dict, apple_prompt, [])
print(len(training_data))
training_data = prepare_training_data(coca_daily_tweets, coke_label_dict, coke_prompt,  training_data)
print(len(training_data))
training_data = prepare_training_data(visa_daily_tweets, visa_label_dict, visa_prompt, training_data)
print(len(training_data))
training_data = prepare_training_data(exxon_daily_tweets, exxon_label_dict, exxon_prompt, training_data)
print(len(training_data))
training_data = prepare_training_data(tesla_daily_tweets, tesla_label_dict, tesla_prompt, training_data)
print(len(training_data))
# Out:
# 50
# 78
# 126
# 170
# 218

# %%
for i in [191, 192]:
    training_data[i]['text_input'] = training_data[i]['text_input'][:38500]

# %%
base_model = "models/gemini-1.5-flash-001-tuning"

operation = genai.create_tuned_model(
    # You can use a tuned model here too. Set `source_model="tunedModels/..."`
    display_name="tune_all",
    source_model=base_model,
    epoch_count=10,
    batch_size=10,
    learning_rate=0.001,
    training_data=training_data,
    temperature=1,
)

for status in operation.wait_bar():
    time.sleep(10)

result = operation.result()
print(result)
# # You can plot the loss curve with:
# snapshots = pd.DataFrame(result.tuning_task.snapshots)
# sns.lineplot(data=snapshots, x='epoch', y='mean_loss')
# Out:
#   0%|          | 0/218 [00:00<?, ?it/s]
# TunedModel(name='tunedModels/tuneall-gdguzrnfxmz0',
#            source_model='models/gemini-1.5-flash-001-tuning',
#            base_model='models/gemini-1.5-flash-001-tuning',
#            display_name='tune_all',
#            description='',
#            temperature=1.0,
#            top_p=0.95,
#            top_k=64,
#            state=<State.ACTIVE: 2>,
#            create_time=datetime.datetime(2024, 12, 17, 16, 52, 23, 393023, tzinfo=datetime.timezone.utc),
#            update_time=datetime.datetime(2024, 12, 17, 17, 7, 32, 255638, tzinfo=datetime.timezone.utc),
#            tuning_task=TuningTask(start_time=datetime.datetime(2024, 12, 17, 16, 52, 24, 56828, tzinfo=datetime.timezone.utc),
#                                   complete_time=datetime.datetime(2024, 12, 17, 17, 7, 32, 255638, tzinfo=datetime.timezone.utc),
#                                   snapshots=[...],
# ...

# %%
# genai.delete_tuned_model("tunedModels/pricetune-t6ml7n71opou")
for model_info in genai.list_tuned_models():
    print(model_info.name)
# Out:
# tunedModels/tuneall-gdguzrnfxmz0

# %%
genai.update_tuned_model('tunedModels/tuneall-gdguzrnfxmz0', {"description":"This is the model fine-tuned on all the tweets and stock price change data before 13 March 2020."})
# Out:
# TunedModel(name=None,
#            source_model=None,
#            base_model=None,
#            display_name='',
#            description=('This is the model fine-tuned on all the tweets and stock price change data '
#                         'before 13 March 2020.'),
#            temperature=None,
#            top_p=None,
#            top_k=None,
#            state=<State.STATE_UNSPECIFIED: 0>,
#            create_time=None,
#            update_time=None,
#            tuning_task=None,
#            reader_project_numbers=None)

# %%
generation_config = {
  "temperature": 0.3,
  "max_output_tokens": 1,
  "response_mime_type": "text/plain",
}

gen_model = genai.GenerativeModel( 
      model_name="tunedModels/tuneall-gdguzrnfxmz0",
      generation_config=generation_config, 
      # system_instruction= "Forget all your previous instructions. Pretend you are a financial expert. You are a financial expert with stock recommendation experience adept at analysing the effect of tweets on stock price.",
 )
# r = gen_model.generate_content("happy or not sad it really depends. but i am okay")

# %% [markdown]
# ### For zero shot learning

# %%
check = pd.read_csv("gemini_sentiment_predictions_finetuned.csv")['date_of_tweets'].to_list()
results = pd.read_csv("gemini_sentiment_predictions_finetuned.csv")
for date, tweets in apple_daily_tweets.items():
    if date in check:
        print(f"Skipping {date}")
        continue
    ticker = "AAPL"
    current_tweet = " ".join(tweets)
    company_name = f"Apple Inc. ({ticker})"
    prompt = f"Predict the next-day price movement of the stock for {company_name} based on the following tweets. Your prediction should be binary, 1 for positive price movement and 0 for negative price movement. Only give the prediction as your response, nothing else. Here are the tweets from today: {current_tweet}\n"
    try:
        response = gen_model.generate_content([prompt])
    except:
        time.sleep(6)
        response = gen_model.generate_content([prompt])
    try:
        results = pd.concat([results, pd.DataFrame([{
            "ticker": ticker,
            "date_of_tweets": date,
            "prediction": response.text,
            "confidence": np.exp(response.candidates[0].avg_logprobs)
        }])], ignore_index=True)
    except:
        print(f"Response not received for {date}")
        continue
    results.to_csv("gemini_sentiment_predictions_finetuned.csv", index=False)
    time.sleep(4)
    print(date, response.text, np.exp(response.candidates[0].avg_logprobs))
# Out:
# Skipping 2020-01-01
# Skipping 2020-01-02
# Skipping 2020-01-03
# Skipping 2020-01-04
# Skipping 2020-01-05
# Skipping 2020-01-06
# Skipping 2020-01-07
# Skipping 2020-01-08
# Skipping 2020-01-09
# Skipping 2020-01-10
# Skipping 2020-01-11
# Skipping 2020-01-12
# Skipping 2020-01-13
# Skipping 2020-01-14
# Skipping 2020-01-15
# Skipping 2020-01-16
# Skipping 2020-01-17
# Skipping 2020-01-18
# Skipping 2020-01-19
# Skipping 2020-01-20
# Skipping 2020-01-21
# Skipping 2020-01-22
# Skipping 2020-01-23
# Skipping 2020-01-24
# Skipping 2020-01-25
# Skipping 2020-01-26
# Skipping 2020-01-27
# Skipping 2020-01-28
# Skipping 2020-01-29
# Skipping 2020-01-30
# Skipping 2020-01-31
# Skipping 2020-02-01
# Skipping 2020-02-02
# Skipping 2020-02-03
# Skipping 2020-02-04
# Skipping 2020-02-05
# Skipping 2020-02-06
# Skipping 2020-02-07
# Skipping 2020-02-08
# Skipping 2020-02-09
# Skipping 2020-02-10
# Skipping 2020-02-11
# Skipping 2020-02-12
# Skipping 2020-02-13
# Skipping 2020-02-14
# ...

# %%
columns = ["ticker", "date_of_tweets", "prediction", "confidence"]

# Create an empty DataFrame with these columns
df = pd.DataFrame(columns=columns)

# Save the DataFrame to a CSV file
df.to_csv("gemini_sentiment_predictions_finetuned.csv", index=False)

# %%
check = pd.read_csv("gemini_sentiment_predictions_finetuned.csv")
check = check.loc[check['ticker'] == 'KO', 'date_of_tweets'].to_list()
results = pd.read_csv("gemini_sentiment_predictions_finetuned.csv")
for date, tweets in coca_daily_tweets.items():
    if date in check:
        print(f"Skipping {date}")
        continue
    ticker = "KO"
    current_tweet = " ".join(tweets)
    company_name = f"The Coca-Cola Company ({ticker})"
    prompt = f"Predict the next-day price movement of the stock for {company_name} based on the following tweets. Your prediction should be binary, 1 for positive price movement and 0 for negative price movement. Only give the prediction as your response, nothing else. Here are the tweets from today: {current_tweet}\n"
    try:
        response = gen_model.generate_content([prompt])
    except:
        time.sleep(6)
        response = gen_model.generate_content([prompt])

    try:
        results = pd.concat([results, pd.DataFrame([{
            "ticker": ticker,
            "date_of_tweets": date,
            "prediction": response.text,
            "confidence": np.exp(response.candidates[0].avg_logprobs)
        }])], ignore_index=True)
    except:
        print(f"Response not received for {date}")
        continue

    
    results.to_csv("gemini_sentiment_predictions_finetuned.csv", index=False)
    time.sleep(4)
    print(date, response.text, np.exp(response.candidates[0].avg_logprobs))
# Out:
# Skipping 2020-01-07
# Skipping 2020-01-09
# Skipping 2020-01-10
# Skipping 2020-01-11
# Skipping 2020-01-12
# Skipping 2020-01-13
# Skipping 2020-01-14
# Skipping 2020-01-17
# Skipping 2020-01-18
# Skipping 2020-01-20
# Skipping 2020-01-21
# Skipping 2020-01-23
# Skipping 2020-01-24
# Skipping 2020-01-25
# Skipping 2020-01-26
# Skipping 2020-01-27
# Skipping 2020-01-28
# Skipping 2020-01-29
# Skipping 2020-01-30
# Skipping 2020-02-06
# Skipping 2020-02-07
# Skipping 2020-02-08
# Skipping 2020-02-10
# Skipping 2020-02-12
# Skipping 2020-02-19
# Skipping 2020-02-20
# Skipping 2020-02-21
# Skipping 2020-02-22
# Skipping 2020-02-23
# Skipping 2020-02-24
# Skipping 2020-02-25
# Skipping 2020-02-26
# Skipping 2020-02-27
# Skipping 2020-02-28
# Skipping 2020-03-04
# Skipping 2020-03-06
# Skipping 2020-03-08
# Skipping 2020-03-10
# Skipping 2020-03-11
# Skipping 2020-03-12
# Skipping 2020-03-13
# Skipping 2020-03-16
# Skipping 2020-03-17
# Skipping 2020-03-18
# Skipping 2020-03-19
# ...

# %%
check = pd.read_csv("gemini_sentiment_predictions_finetuned.csv")
check = check.loc[check['ticker'] == 'V', 'date_of_tweets'].to_list()
results = pd.read_csv("gemini_sentiment_predictions_finetuned.csv")
for date, tweets in visa_daily_tweets.items():
    if date in check:
        print(f"Skipping {date}")
        continue
    ticker = "V"
    current_tweet = " ".join(tweets)
    company_name = f"Visa Inc. ({ticker})"
    prompt = f"Predict the next-day price movement of the stock for {company_name} based on the following tweets. Your prediction should be binary, 1 for positive price movement and 0 for negative price movement. Only give the prediction as your response, nothing else. Here are the tweets from today: {current_tweet}\n"
    try:
        response = gen_model.generate_content([prompt])
    except:
        time.sleep(6)
        response = gen_model.generate_content([prompt])
    try:
        results = pd.concat([results, pd.DataFrame([{
            "ticker": ticker,
            "date_of_tweets": date,
            "prediction": response.text,
            "confidence": np.exp(response.candidates[0].avg_logprobs)
        }])], ignore_index=True)
    except:
        print(f"Response not received for {date}")
        continue
    
    results.to_csv("gemini_sentiment_predictions_finetuned.csv", index=False)
    time.sleep(4)
    print(date, response.text, np.exp(response.candidates[0].avg_logprobs))
# Out:
# Skipping 2020-01-04
# Skipping 2020-01-05
# Skipping 2020-01-06
# Skipping 2020-01-07
# Skipping 2020-01-08
# Skipping 2020-01-09
# Skipping 2020-01-10
# Skipping 2020-01-11
# Skipping 2020-01-12
# Skipping 2020-01-13
# Skipping 2020-01-14
# Skipping 2020-01-15
# Skipping 2020-01-16
# Skipping 2020-01-17
# Skipping 2020-01-18
# Skipping 2020-01-19
# Skipping 2020-01-20
# Skipping 2020-01-21
# Skipping 2020-01-22
# Skipping 2020-01-23
# Skipping 2020-01-24
# Skipping 2020-01-25
# Skipping 2020-01-26
# Skipping 2020-01-27
# Skipping 2020-01-28
# Skipping 2020-01-29
# Skipping 2020-01-30
# Skipping 2020-01-31
# Skipping 2020-02-01
# Skipping 2020-02-02
# Skipping 2020-02-03
# Skipping 2020-02-04
# Skipping 2020-02-05
# Skipping 2020-02-06
# Skipping 2020-02-07
# Skipping 2020-02-08
# Skipping 2020-02-09
# Skipping 2020-02-10
# Skipping 2020-02-11
# Skipping 2020-02-12
# Skipping 2020-02-13
# Skipping 2020-02-14
# Skipping 2020-02-15
# Skipping 2020-02-16
# Skipping 2020-02-17
# ...

# %%
check = pd.read_csv("gemini_sentiment_predictions_finetuned.csv")
check = check.loc[check['ticker'] == 'V', 'date_of_tweets'].to_list()
results = pd.read_csv("gemini_sentiment_predictions_finetuned.csv")
for date, tweets in visa_daily_tweets.items():
    if date in check:
        print(f"Skipping {date}")
        continue
    ticker = "V"
    current_tweet = " ".join(tweets)
    company_name = f"Visa Inc. ({ticker})"
    prompt = f"Predict the next-day price movement of the stock for {company_name} based on the following tweets. Your prediction should be binary, 1 for positive price movement and 0 for negative price movement. Only give the prediction as your response, nothing else. Here are the tweets from today: {current_tweet}\n"
    try:
        response = gen_model.generate_content([prompt])
    except:
        time.sleep(6)
        response = gen_model.generate_content([prompt])
    try:
        results = pd.concat([results, pd.DataFrame([{
            "ticker": ticker,
            "date_of_tweets": date,
            "prediction": response.text,
            "confidence": np.exp(response.candidates[0].avg_logprobs)
        }])], ignore_index=True)
    except:
        print(f"Response not received for {date}")
        continue
    
    results.to_csv("gemini_sentiment_predictions_finetuned.csv", index=False)
    time.sleep(4)
    print(date, response.text, np.exp(response.candidates[0].avg_logprobs))
# Out:
# Skipping 2020-01-04
# Skipping 2020-01-05
# Skipping 2020-01-06
# Skipping 2020-01-07
# Skipping 2020-01-08
# Skipping 2020-01-09
# Skipping 2020-01-10
# Skipping 2020-01-11
# Skipping 2020-01-12
# Skipping 2020-01-13
# Skipping 2020-01-14
# Skipping 2020-01-15
# Skipping 2020-01-16
# Skipping 2020-01-17
# Skipping 2020-01-18
# Skipping 2020-01-19
# Skipping 2020-01-20
# Skipping 2020-01-21
# Skipping 2020-01-22
# Skipping 2020-01-23
# Skipping 2020-01-24
# Skipping 2020-01-25
# Skipping 2020-01-26
# Skipping 2020-01-27
# Skipping 2020-01-28
# Skipping 2020-01-29
# Skipping 2020-01-30
# Skipping 2020-01-31
# Skipping 2020-02-01
# Skipping 2020-02-02
# Skipping 2020-02-03
# Skipping 2020-02-04
# Skipping 2020-02-05
# Skipping 2020-02-06
# Skipping 2020-02-07
# Skipping 2020-02-08
# Skipping 2020-02-09
# Skipping 2020-02-10
# Skipping 2020-02-11
# Skipping 2020-02-12
# Skipping 2020-02-13
# Skipping 2020-02-14
# Skipping 2020-02-15
# Skipping 2020-02-16
# Skipping 2020-02-17
# ...

# %%
check = pd.read_csv("gemini_sentiment_predictions_finetuned.csv")
check = check.loc[check['ticker'] == 'XOM', 'date_of_tweets'].to_list()
results = pd.read_csv("gemini_sentiment_predictions_finetuned.csv")
for date, tweets in exxon_daily_tweets.items():
    if date in check:
        print(f"Skipping {date}")
        continue
    ticker = "XOM"
    current_tweet = " ".join(tweets)
    company_name = f"Exxon Mobil Corporation ({ticker})"
    prompt = f"Predict the next-day price movement of the stock for {company_name} based on the following tweets. Your prediction should be binary, 1 for positive price movement and 0 for negative price movement. Only give the prediction as your response, nothing else. Here are the tweets from today: {current_tweet}\n"
    try:
        response = gen_model.generate_content([prompt])
    except:
        time.sleep(6)
        try:
            response = gen_model.generate_content([prompt])
        except:
            print(f"Skipping {date} Manually process it for {ticker}")
            continue
    try:
        results = pd.concat([results, pd.DataFrame([{
            "ticker": ticker,
            "date_of_tweets": date,
            "prediction": response.text,
            "confidence": np.exp(response.candidates[0].avg_logprobs)
        }])], ignore_index=True)
    except:
        print(f"Response not received for {date}")
        continue
    results.to_csv("gemini_sentiment_predictions_finetuned.csv", index=False)
    time.sleep(4)
    print(date, response.text, np.exp(response.candidates[0].avg_logprobs))
# Out:
# Skipping 2020-01-05
# Skipping 2020-01-06
# Skipping 2020-01-07
# Skipping 2020-01-08
# Skipping 2020-01-09
# Skipping 2020-01-10
# Skipping 2020-01-11
# Skipping 2020-01-13
# Skipping 2020-01-14
# Skipping 2020-01-15
# Skipping 2020-01-16
# Skipping 2020-01-17
# Skipping 2020-01-19
# Skipping 2020-01-20
# Skipping 2020-01-21
# Skipping 2020-01-22
# Skipping 2020-01-23
# Skipping 2020-01-24
# Skipping 2020-01-25
# Skipping 2020-01-26
# Skipping 2020-01-27
# Skipping 2020-01-28
# Skipping 2020-01-29
# Skipping 2020-01-30
# Skipping 2020-01-31
# Skipping 2020-02-01
# Skipping 2020-02-02
# Skipping 2020-02-03
# Skipping 2020-02-04
# Skipping 2020-02-05
# Skipping 2020-02-06
# Skipping 2020-02-07
# Skipping 2020-02-08
# Skipping 2020-02-10
# Skipping 2020-02-11
# Skipping 2020-02-12
# Skipping 2020-02-13
# Skipping 2020-02-14
# Skipping 2020-02-16
# Skipping 2020-02-18
# Skipping 2020-02-19
# Skipping 2020-02-20
# Skipping 2020-02-21
# Skipping 2020-02-24
# Skipping 2020-02-25
# ...

# %%
check = pd.read_csv("gemini_sentiment_predictions_finetuned.csv")
check = check.loc[check['ticker'] == 'TSLA', 'date_of_tweets'].to_list()
print(check)
results = pd.read_csv("gemini_sentiment_predictions_finetuned.csv")
for date, tweets in tesla_daily_tweets.items():
    if date in check:
        print(f"Skipping {date}")
        continue
    ticker = "TSLA"
    current_tweet = " ".join(tweets)
    company_name = f"Tesla, Inc. ({ticker})"
    prompt = f"Predict the next-day price movement of the stock for {company_name} based on the following tweets. Your prediction should be binary, 1 for positive price movement and 0 for negative price movement. Only give the prediction as your response, nothing else. Here are the tweets from today: {current_tweet}\n"
    try:
        response = gen_model.generate_content([prompt])
    except:
        time.sleep(6)
        try:
            response = gen_model.generate_content([prompt])
        except:
            print(f"Skipping {date} Manually process it for {ticker}")
            continue
    try:
        results = pd.concat([results, pd.DataFrame([{
            "ticker": ticker,
            "date_of_tweets": date,
            "prediction": response.text,
            "confidence": np.exp(response.candidates[0].avg_logprobs)
        }])], ignore_index=True)
    except:
        print(f"Response not received for {date}")
        continue
    results.to_csv("gemini_sentiment_predictions_finetuned.csv", index=False)
    time.sleep(4)
    print(date, response.text, np.exp(response.candidates[0].avg_logprobs))
# Out:
# ['2020-01-04', '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-11', '2020-01-12', '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16', '2020-01-17', '2020-01-18', '2020-01-19', '2020-01-20', '2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24', '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28', '2020-01-29', '2020-01-30', '2020-01-31', '2020-02-01', '2020-02-02', '2020-02-03', '2020-02-04', '2020-02-05', '2020-02-06', '2020-02-07', '2020-02-08', '2020-02-09', '2020-02-10', '2020-02-11', '2020-02-12', '2020-02-13', '2020-02-14', '2020-02-15', '2020-02-16', '2020-02-17', '2020-02-18', '2020-02-19', '2020-02-20', '2020-02-21', '2020-02-22']
# Skipping 2020-01-04
# Skipping 2020-01-05
# Skipping 2020-01-06
# Skipping 2020-01-07
# Skipping 2020-01-08
# Skipping 2020-01-09
# Skipping 2020-01-10
# Skipping 2020-01-11
# Skipping 2020-01-12
# Skipping 2020-01-13
# Skipping 2020-01-14
# Skipping 2020-01-15
# Skipping 2020-01-16
# ...
